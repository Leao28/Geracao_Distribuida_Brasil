# %% [markdown]
# # **Análise da Geração Distribuída no Brasil**
# <font size="5">**Análise Estatística**</font>
#
# ---
# <p style='text-align: right;'> Por Henrique Leão </p>

# %% [markdown]
# ##  **1. Considerações Iniciais**

# %% [markdown]
# O presente Notebook tem como finalidade explorar estatisticamente os DataFrames provenientes dos Scripts '1_Manipulando_Dados.py' e '2_Criando_DataFrames', dessa forma iniciando o estudo dos dados ao qual o projeto se propõe.
#
# Essa parte do estudo contém:
#
# * Análise das Distribuições de Frequências
# * <font color=blue> Em desenvolvimento </font>
# * <font color=blue> Em desenvolvimento </font>

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df_Base = pd.read_csv('../Output/DataFrame_Base.csv', sep = ';', encoding = 'utf-8')
df_Base.dtypes
# Out:
# Concessionaria                object
# Sigla                         object
# Codigo_GD                     object
# Tipo_Consumidor               object
# Classe_Consumo                object
# Grupo_Tarifario               object
# Municipio                     object
# UF                            object
# Regiao                        object
# Tipo_Geracao                  object
# Fonte_Geracao                 object
# Porte_Geracao                 object
# Pot_Instalada_kW             float64
# Modalidade                    object
# Unidades_Recebem_Creditos      int64
# SubEstacao                    object
# Data_Conexao                  object
# Latitude_GD                   object
# Longitude_GD                  object
# Latitude_Sub                  object
# Longitude_Sub                 object
# ID_Classe                      int64
# ID_Grupo                       int64
# ID_UF                          int64
# ID_Municipio                   int64
# dtype: object

# %%
# Distribuição de Frequências

def Dist_Freq(Parametro):
    frequencia_absoluta = df_Base[Parametro].value_counts()
    frequencia_percentual = (df_Base[Parametro].value_counts(normalize = True) * 100).round(2)
    distribuicao = pd.DataFrame({'Frequencia': frequencia_absoluta, 'Percentual (%)': frequencia_percentual})
    distribuicao.rename_axis(Parametro, axis = 'columns', inplace = True)
    return distribuicao

def Dist_Freq_2(Parametro_1, Parametro_2):
    frequencia_absoluta = df_Base.groupby([Parametro_1])[Parametro_2].value_counts()
    frequencia_percentual = (df_Base.groupby([Parametro_1])[Parametro_2].value_counts(normalize = True) * 100).round(2)
    distribuicao = pd.DataFrame({'Frequencia': frequencia_absoluta, 'Percentual (%)': frequencia_percentual})
    return distribuicao

# %%
Dist_Freq('Classe_Consumo')\
    .style.format({'Percentual (%)': '{:.2f}'})\
    .bar(subset = ['Percentual (%)'], color='lightgreen', height=50, width=60)
# Out:
# <style type="text/css">
# #T_0f9fa_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_0f9fa_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.8%, transparent 9.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_0f9fa_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 6.0%, transparent 6.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_0f9fa_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 1.5%, transparent 1.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_0f9fa_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.2%, transparent 0.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_0f9fa_row5_col1, #T_0f9fa_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.0%, transparent 0.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_0f9fa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Classe_Consumo</th>
#       <th id="T_0f9fa_level0_col0" class="col_heading level0 col0" >Frequencia</th>
#       <th id="T_0f9fa_level0_col1" class="col_heading level0 col1" >Percentual (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f9fa_level0_row0" class="row_heading level0 row0" >Residencial</th>
#       <td id="T_0f9fa_row0_col0" class="data row0 col0" >714987</td>
#       <td id="T_0f9fa_row0_col1" class="data row0 col1" >77.35</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row1" class="row_heading level0 row1" >Comercial</th>
#       <td id="T_0f9fa_row1_col0" class="data row1 col0" >117180</td>
#       <td id="T_0f9fa_row1_col1" class="data row1 col1" >12.68</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row2" class="row_heading level0 row2" >Rural</th>
#       <td id="T_0f9fa_row2_col0" class="data row2 col0" >71163</td>
#       <td id="T_0f9fa_row2_col1" class="data row2 col1" >7.70</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row3" class="row_heading level0 row3" >Industrial</th>
#       <td id="T_0f9fa_row3_col0" class="data row3 col0" >18010</td>
#       <td id="T_0f9fa_row3_col1" class="data row3 col1" >1.95</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row4" class="row_heading level0 row4" >Poder Público</th>
#       <td id="T_0f9fa_row4_col0" class="data row4 col0" >2741</td>
#       <td id="T_0f9fa_row4_col1" class="data row4 col1" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row5" class="row_heading level0 row5" >Serviço Público</th>
#       <td id="T_0f9fa_row5_col0" class="data row5 col0" >216</td>
#       <td id="T_0f9fa_row5_col1" class="data row5 col1" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_0f9fa_level0_row6" class="row_heading level0 row6" >Iluminação pública</th>
#       <td id="T_0f9fa_row6_col0" class="data row6 col0" >54</td>
#       <td id="T_0f9fa_row6_col1" class="data row6 col1" >0.01</td>
#     </tr>
#   </tbody>
# </table>

# %%
Dist_Freq_2('Classe_Consumo', 'Regiao')\
    .style.format({'Percentual (%)': '{:.2f}'})\
    .bar(subset = ['Percentual (%)'], color='lightgreen', height=50, width=60)
# Out:
# <style type="text/css">
# #T_44b06_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.7%, transparent 47.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 33.3%, transparent 33.3%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 30.8%, transparent 30.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row3_col1, #T_44b06_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.6%, transparent 18.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 7.5%, transparent 7.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 56.2%, transparent 56.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 40.9%, transparent 40.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row7_col1, #T_44b06_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 17.9%, transparent 17.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 5.1%, transparent 5.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 57.4%, transparent 57.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 43.5%, transparent 43.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row12_col1, #T_44b06_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 21.7%, transparent 21.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.2%, transparent 13.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 2.1%, transparent 2.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 49.5%, transparent 49.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 38.2%, transparent 38.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 16.2%, transparent 16.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 15.3%, transparent 15.3%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 55.0%, transparent 55.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.4%, transparent 28.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 27.7%, transparent 27.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row23_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.2%, transparent 18.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 8.6%, transparent 8.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 53.5%, transparent 53.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.8%, transparent 47.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.8%, transparent 18.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.4%, transparent 14.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row29_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.4%, transparent 3.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row31_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 41.5%, transparent 41.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 11.5%, transparent 11.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_44b06_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.2%, transparent 3.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_44b06">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44b06_level0_col0" class="col_heading level0 col0" >Frequencia</th>
#       <th id="T_44b06_level0_col1" class="col_heading level0 col1" >Percentual (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Classe_Consumo</th>
#       <th class="index_name level1" >Regiao</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44b06_level0_row0" class="row_heading level0 row0" rowspan="5">Comercial</th>
#       <th id="T_44b06_level1_row0" class="row_heading level1 row0" >Sudeste</th>
#       <td id="T_44b06_row0_col0" class="data row0 col0" >40506</td>
#       <td id="T_44b06_row0_col1" class="data row0 col1" >34.57</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row1" class="row_heading level1 row1" >Nordeste</th>
#       <td id="T_44b06_row1_col0" class="data row1 col0" >28319</td>
#       <td id="T_44b06_row1_col1" class="data row1 col1" >24.17</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row2" class="row_heading level1 row2" >Sul</th>
#       <td id="T_44b06_row2_col0" class="data row2 col0" >26168</td>
#       <td id="T_44b06_row2_col1" class="data row2 col1" >22.33</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row3" class="row_heading level1 row3" >Centro Oeste</th>
#       <td id="T_44b06_row3_col0" class="data row3 col0" >15833</td>
#       <td id="T_44b06_row3_col1" class="data row3 col1" >13.51</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row4" class="row_heading level1 row4" >Norte</th>
#       <td id="T_44b06_row4_col0" class="data row4 col0" >6354</td>
#       <td id="T_44b06_row4_col1" class="data row4 col1" >5.42</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level0_row5" class="row_heading level0 row5" rowspan="5">Iluminação pública</th>
#       <th id="T_44b06_level1_row5" class="row_heading level1 row5" >Nordeste</th>
#       <td id="T_44b06_row5_col0" class="data row5 col0" >22</td>
#       <td id="T_44b06_row5_col1" class="data row5 col1" >40.74</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row6" class="row_heading level1 row6" >Sudeste</th>
#       <td id="T_44b06_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_44b06_row6_col1" class="data row6 col1" >29.63</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row7" class="row_heading level1 row7" >Centro Oeste</th>
#       <td id="T_44b06_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_44b06_row7_col1" class="data row7 col1" >12.96</td>
#     </tr>
#     <tr>
#       <th id="T_44b06_level1_row8" class="row_heading level1 row8" >Sul</th>
#       <td id="T_44b06_row8_col0" class="data
